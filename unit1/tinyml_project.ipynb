# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('dataset_soil.csv')
data
# Out:
#     moisture1  moisture2  moisture3  moisture4  moisture5  water_needed
# 0        0.70       0.64       0.73       0.40       0.02          0.02
# 1        0.70       0.64       0.71       0.39       0.02          0.02
# 2        0.68       0.62       0.68       0.39       0.03          0.04
# 3        0.69       0.62       0.68       0.39       0.02          0.03
# 4        0.69       0.61       0.68       0.38       0.02          0.03
# ..        ...        ...        ...        ...        ...           ...
# 94       0.42       0.42       0.41       0.23       0.03          0.70
# 95       0.42       0.42       0.41       0.24       0.02          0.70
# 96       0.42       0.42       0.42       0.23       0.02          0.71
# 97       0.41       0.41       0.41       0.22       0.03          0.71
# 98       0.42       0.41       0.41       0.22       0.02          0.71
#
# [99 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99 entries, 0 to 98
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   moisture1     99 non-null     float64
#  1   moisture2     99 non-null     float64
#  2   moisture3     99 non-null     float64
#  3   moisture4     99 non-null     float64
#  4   moisture5     99 non-null     float64
#  5   water_needed  99 non-null     float64
# dtypes: float64(6)
# memory usage: 4.8 KB

# %%
real_x = data.iloc[:,:5].values
#real_x

# %%
real_y = data.iloc[:,5].values
#real_y

# %%
from sklearn.model_selection import train_test_split

# %%
train_x, test_x, train_y, test_y =  train_test_split(real_x,real_y,test_size=0.3, random_state=99)

# %%
train_x.shape, train_y.shape
# Out:
# ((69, 5), (69,))

# %%
from sklearn.linear_model import LinearRegression
le = LinearRegression()

# %%
le.fit(train_x,train_y)
# Out:
# LinearRegression()

# %%
y_pred = le.predict(test_x)
#y_pred

# %%
from sklearn.metrics import r2_score

# %%
r2_score(test_y,y_pred)
# Out:
# 0.9814839209668262

# %%
le.coef_
# Out:
# array([-2.64765132, -0.48181785,  0.91482268, -0.75024825, -1.26502421])

# %%
le.intercept_
# Out:
# 1.823981902783127

# %%
# y = ax1 + bx2 + cx3 + dx4 + ex5 + f
# a = -2.64765132
# b = -0.48181785
# c = 0.91482268
# d = -0.75024825
# e = -1.26502421
# f = 1.823981902783127
